# %%
# input data
import json
import pandas as pd

with open("../data/input_data.json", "r", encoding="utf-8") as f:
    input_data = json.load(f)
    
subject, description = input_data['dataset_title_etc_main'], input_data['dataset_expl_etc_main']

df_article = pd.read_csv('../data/search_results_article.csv', encoding='UTF-8', low_memory=False)
df_data = pd.read_csv('../data/search_results_dataset.csv', encoding='UTF-8', low_memory=False)

cleaned_df_data = (
    df_data[
        ['svc_id', 'dataset_title_etc_main', 'dataset_expl_etc_main','dataset_pub_dt_pc', 'dataset_kywd_etc_main', 'dataset_creator_etc_main', 'dataset_lndgpg', 'query']
    ]
    .rename(
        columns={
            'svc_id': 'ID',
            'dataset_title_etc_main': 'title',
            'dataset_expl_etc_main': 'description',
            'dataset_pub_dt_pc': 'pubyear',
            'dataset_kywd_etc_main': 'keyword',
            'dataset_creator_etc_main': 'author',
            'dataset_lndgpg': 'URL',
        }
    )
)
cleaned_df_data['category'] = 'dataset'

cleaned_df_arti = (
    df_article[
        ['CN', 'Title', 'Abstract', 'Pubyear', 'Keyword', 'Author', 'ContentURL', 'query']
    ]
    .rename(
        columns={
            'CN': 'ID',
            'Title': 'title',
            'Abstract': 'description',
            'Pubyear': 'pubyear',
            'Keyword': 'keyword',
            'Author': 'author',
            'ContentURL': 'URL'
        }
    )
)
cleaned_df_arti['category'] = 'article'

df = pd.concat([cleaned_df_arti, cleaned_df_data], ignore_index=True)

# %% [markdown]
# # 임베딩을 통한 점수 생성 방법

# %%
# text-embedding-3-small 사용

from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.schema import Document
import pandas as pd
from tqdm import tqdm

df['title'] = df['title'].fillna('')
df['description'] = df['description'].fillna('')

MAX_LENGTH = 1000
df['description'] = df['description'].str.slice(0, MAX_LENGTH)

texts = (df['title'] + " " +
        df['description']).tolist()

# 2. 임베딩 객체 생성
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# 3. Document 객체로 변환
docs = [Document(page_content=text, metadata={"ID": row.ID}) 
        for text, row in zip(texts, df.itertuples())]

batch_size = 500
stores = []
for i in tqdm(range(0, len(docs), batch_size)):
    batch = docs[i:i+batch_size]
    store = FAISS.from_documents(batch, embeddings)
    stores.append(store)

# 부분 벡터스토어 통합
vectorstore = stores[0]
for s in stores[1:]:
    vectorstore.merge_from(s)

# 5. 쿼리 임베딩 생성
query = subject + " " + description
query_embedding = embeddings.embed_query(query)

# 6. 유사 문서 검색
results_with_score = vectorstore.similarity_search_with_score_by_vector(query_embedding, k=20)

# 7. 결과 출력
relevance_df = pd.DataFrame([
    {
        "ID": r.metadata.get("ID"),
        "relevance": score,
    }
    for r, score in results_with_score
]).sort_values(by="relevance", ascending=True)

relevance_df = relevance_df.merge(
    df[['ID', 'title', 'description']],
    on='ID',
    how='left'
)

display(relevance_df)
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.30s/it]
#                                   ID  relevance  \
# 0   b37f0c9413eeb7c45f6fe31cbe3a41ef   0.032391
# 1   a83eb22a4a62949d83c70662acdf439a   0.572106
# 2   4f8e04de8044dd201965353514748c13   0.765774
# 3   8a296da6f0f22b607daeabd129f789c3   0.815034
# 4   27be08ea55b6e29be994c74b13b82595   0.817217
# 5   35eeb76af7e1bdb0e31f1d28dbd315fb   0.841749
# 6   c9956a897c5342cadc56442d408817a2   0.874056
# 7   5af7ee092c0425a4424cd6fec7a3e1ac   0.914127
# 8   87b79f3640c97ad515c13351fe526224   0.918718
# 9                       NART70277933   0.929998
# 10  0f5da4c2f7d0eeef9c720b60c998628d   0.955532
# 11  175af073d420cd3aa8b18fc8f7360e4e   0.965359
# 12  af4ff46e19ec8314e719b0402c8c090a   0.969025
# 13  c159c72a5ceead51b7d3bcef6e7122e1   0.972393
# 14  5a27d0958baf27c7372453fe940b4db0   0.977592
# 15  02cc2382f78a16632f66c3de6013bd81   0.980088
# 16  8be76b7e70b8ffa54fb6ac5a530c0f0e   0.982316
# 17  0ec64d1fc9ec022f7529050d71197346   0.983454
# 18  3c81f57da77b6cd77b261d4fb1522771   1.006235
# 19  451652c7b01df31b049e9ae30746897b   1.019458
#
#                                                 title  \
# 0   Architectural Urbanism: Melbourne/Seoul - KTA ...
# 1   Urban Architectures (Court House, George+Murph...
# 2                                           Urban box
# 3                                     Saturation City
# 4                                             Crownie
# 5   Section (Charles Street House) + Model (Tarilt...
# 6   Urban Still Lifes (with mops and brooms): Beij...
# 7                                 K2K Design Proposal
# 8                 Carved Ground: residence and studio
# 9                  Large screens as creative clusters
# 10  Murray River Maps, Tidal Garden, McMillan Road...
# 11  Master plan for Dandenong Civic Centre - Rush\...
# 12                          Lyons Architecture Office
# 13                       Australian Garden Cranbourne
# 14                Geelong Library and Heritage Centre
# 15                  Warburton Trail Pedestrian Bridge
# 16                                            Electro
# 17                       Centenary Square, Parramatta
# 18                                         Hamer Hall
# 19  'Stock Exchange', 'Trapeze', 'St. Kilda Rd' (3...
#
#                                           description
# 0   BACKGROUND: 'Architectural Urbanism: Melbourne...
# 1   RESEARCH BACKGROUND: Court House, George+Murph...
# 2   RESEARCH BACKGROUND: Urban Box was one of 4 pr...
# 3   BACKGROUND In 2010 the researcher's collaborat...
# 4   'Peter Corrigan: cities of hope' exhibition at...
# 5   RESEARCH BACKGROUND: X-field is an interdiscip...
# 6   RESEARCH BACKGROUND: The 'Urban Still Life (wi...
# 7   BACKGROUND: The K2K design proposal, developed...
# 8   RESEARCH BACKGROUND: 'Carved ground' is one st...
# 9   This paper begins by situating the large scree...
# 10  RESEARCH BACKGROUND: Mobile Landscapes (III) w...
# 11  RESEARCH BACKGROUND: Paul Carter's Material Th...
# 12  RESEARCH BACKGROUND The commission for this pr...
# 13  RESEARCH BACKGROUND: Australian Garden is a ma...
# 14  RESEARCH BACKGROUND: The Geelong Library and H...
# 15  RESEARCH BACKGROUND The project was an invited...
# 16  Electro was one of three works Redfern created...
# 17  RESEARCH BACKGROUND: Anton James (a principal ...
# 18  RESEARCH BACKGROUND: Hamer Hall is Melbourne's...
# 19  BACKGROUND Conland's curatorial objective of e...

# %% [markdown]
# ## 분야별로 나누기

# %%
# 제목

from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.schema import Document
import pandas as pd
from tqdm import tqdm

df['title'] = df['title'].fillna('')

texts = (df['title']).tolist()

# 2. 임베딩 객체 생성
embeddings_title = OpenAIEmbeddings(model="text-embedding-3-small")

# 3. Document 객체로 변환
docs_title = [Document(page_content=text, metadata={"ID": row.ID}) 
        for text, row in zip(texts, df.itertuples())]

batch_size = 500
stores = []
for i in tqdm(range(0, len(docs_title), batch_size)):
    batch = docs_title[i:i+batch_size]
    store = FAISS.from_documents(batch, embeddings_title)
    stores.append(store)

# 부분 벡터스토어 통합
vectorstore = stores[0]
for s in stores[1:]:
    vectorstore.merge_from(s)

# 5. 쿼리 임베딩 생성
query = subject
query_embedding = embeddings_title.embed_query(query)

# 6. 유사 문서 검색
results_with_score = vectorstore.similarity_search_with_score_by_vector(query_embedding, k=len(texts))

# 7. 결과 출력
relevance_df_title = pd.DataFrame([
    {
        "ID": r.metadata.get("ID"),
        "relevance": score,
    }
    for r, score in results_with_score
]).sort_values(by="relevance", ascending=True)

relevance_df_title = relevance_df_title.merge(
    df[['ID', 'category',  'title', 'description']],
    on='ID',
    how='left'
)

display(relevance_df_title)
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
#                                    ID     relevance category  \
# 0    b37f0c9413eeb7c45f6fe31cbe3a41ef  8.833030e-07  dataset
# 1    a83eb22a4a62949d83c70662acdf439a  7.597810e-01  dataset
# 2                        NPAP14424286  8.514366e-01  article
# 3                        NART90662159  8.575770e-01  article
# 4                       NART130570112  8.681008e-01  article
# ..                                ...           ...      ...
# 160  384ac3e2a4cf0d16d11758f78c26426c  1.873814e+00  dataset
# 161  0d0b434d5bc6537b3d40f690a425179a  1.874088e+00  dataset
# 162  0efc6d4fbaf6ae848785b3f7716cafa7  1.875190e+00  dataset
# 163  5d24ce68a454432a4d8934cd99f506a1  1.875922e+00  dataset
# 164  b33846af9bccac4abbce4af23a43aa0a  2.033729e+00  dataset
#
#                                                  title  \
# 0    Architectural Urbanism: Melbourne/Seoul - KTA ...
# 1    Urban Architectures (Court House, George+Murph...
# 2    Innovative tools for implementing the smart ci...
# 3     Urban Sustainability through Public Architecture
# 4    Sustainable Urbanism and Architectural Design:...
# ..                                                 ...
# 160  Additional file 23 of Implicating genes, pleio...
# 161  Additional file 25 of Implicating genes, pleio...
# 162  Additional file 29 of Implicating genes, pleio...
# 163  Additional file 8 of Implicating genes, pleiot...
# 164                                    He must not cry
#
#                                            description
# 0    BACKGROUND: 'Architectural Urbanism: Melbourne...
# 1    RESEARCH BACKGROUND: Court House, George+Murph...
# 2
# 3    <P>As the sustainability of contemporary citie...
# 4    <P>This academic article delves into the inter...
# ..                                                 ...
# 160  <b>External Organisations</b><br/>Queen Mary U...
# 161  <b>External Organisations</b><br/>Queen Mary U...
# 162  <b>External Organisations</b><br/>Queen Mary U...
# 163  <b>External Organisations</b><br/>Queen Mary U...
# 164  An inaugural partnership between ACMI and Asia...
#
# [165 rows x 5 columns]

# %%
# 설명

from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.schema import Document
import pandas as pd
from tqdm import tqdm

df['description'] = df['description'].fillna('')

MAX_LENGTH = 1000
df['description'] = df['description'].str.slice(0, MAX_LENGTH)

texts = (df['description']).tolist()

# 2. 임베딩 객체 생성
embeddings_description = OpenAIEmbeddings(model="text-embedding-3-small")

# 3. Document 객체로 변환
docs_description = [Document(page_content=text, metadata={"ID": row.ID}) 
        for text, row in zip(texts, df.itertuples())]

batch_size = 500
stores = []
for i in tqdm(range(0, len(docs_description), batch_size)):
    batch = docs_description[i:i+batch_size]
    store = FAISS.from_documents(batch, embeddings_description)
    stores.append(store)

# 부분 벡터스토어 통합
vectorstore = stores[0]
for s in stores[1:]:
    vectorstore.merge_from(s)

# 5. 쿼리 임베딩 생성
query = description
query_embedding = embeddings_description.embed_query(query)

# 6. 유사 문서 검색
results_with_score = vectorstore.similarity_search_with_score_by_vector(query_embedding, k=len(texts))

# 7. 결과 출력
relevance_df_description = pd.DataFrame([
    {
        "ID": r.metadata.get("ID"),
        "relevance": score,
    }
    for r, score in results_with_score
]).sort_values(by="relevance", ascending=True)

relevance_df_description = relevance_df_description.merge(
    df[['ID', 'category',  'title', 'description']],
    on='ID',
    how='left'
)

display(relevance_df_description)
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
#                                    ID  relevance category  \
# 0    b37f0c9413eeb7c45f6fe31cbe3a41ef   0.045485  dataset
# 1    a83eb22a4a62949d83c70662acdf439a   0.536102  dataset
# 2    4f8e04de8044dd201965353514748c13   0.689401  dataset
# 3    8a296da6f0f22b607daeabd129f789c3   0.722418  dataset
# 4    27be08ea55b6e29be994c74b13b82595   0.748554  dataset
# ..                                ...        ...      ...
# 160                      NART80860267   1.699124  article
# 161                      NART70983995   1.699389  article
# 162                      NART56990519   1.719598  article
# 163                      NPAP13611771   1.738940  article
# 164                      NART78101752   1.826653  article
#
#                                                  title  \
# 0    Architectural Urbanism: Melbourne/Seoul - KTA ...
# 1    Urban Architectures (Court House, George+Murph...
# 2                                            Urban box
# 3                                      Saturation City
# 4                                              Crownie
# ..                                                 ...
# 160  Reduced orbitofrontal cortical thickness in ma...
# 161  COMT genotype affects brain white matter pathw...
# 162  Point target probabilistic multiple hypothesis...
# 163    Movie Recommendation System Using Deep Learning
# 164  Vitamin D Status and Bone Mineral Density in C...
#
#                                            description
# 0    BACKGROUND: 'Architectural Urbanism: Melbourne...
# 1    RESEARCH BACKGROUND: Court House, George+Murph...
# 2    RESEARCH BACKGROUND: Urban Box was one of 4 pr...
# 3    BACKGROUND In 2010 the researcher's collaborat...
# 4    'Peter Corrigan: cities of hope' exhibition at...
# ..                                                 ...
# 160  <P><B>Background</B></P><P>The orbitofrontal c...
# 161  <P><B>Abstract</B></P><P>Increased dopamine av...
# 162  <P>Probabilistic Multiple Hypothesis Tracking ...
# 163  <P>It is a challenge to design a movie recomme...
# 164  <P>Low vitamin D has been implicated in reduce...
#
# [165 rows x 5 columns]

# %%
# 키워드

from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain.schema import Document
import pandas as pd
from tqdm import tqdm

df['keyword'] = df['keyword'].fillna('')

texts = (df['keyword']).tolist()

# 2. 임베딩 객체 생성
embeddings_keyword = OpenAIEmbeddings(model="text-embedding-3-small")

# 3. Document 객체로 변환
docs_keyword = [Document(page_content=text, metadata={"ID": row.ID}) 
        for text, row in zip(texts, df.itertuples())]

batch_size = 500
stores = []
for i in tqdm(range(0, len(docs_keyword), batch_size)):
    batch = docs_keyword[i:i+batch_size]
    store = FAISS.from_documents(batch, embeddings_keyword)
    stores.append(store)

# 부분 벡터스토어 통합
vectorstore = stores[0]
for s in stores[1:]:
    vectorstore.merge_from(s)

# 5. 쿼리 임베딩 생성
query = description
query_embedding = embeddings_keyword.embed_query(query)

# 6. 유사 문서 검색
results_with_score = vectorstore.similarity_search_with_score_by_vector(query_embedding, k=len(texts))

# 7. 결과 출력
relevance_df_keyword = pd.DataFrame([
    {
        "ID": r.metadata.get("ID"),
        "relevance": score,
    }
    for r, score in results_with_score
]).sort_values(by="relevance", ascending=True)

relevance_df_keyword = relevance_df_keyword.merge(
    df[['ID', 'category',  'title', 'description']],
    on='ID',
    how='left'
)

display(relevance_df_keyword)
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.00s/it]
#                                    ID  relevance category  \
# 0                        NART70277933   1.012413  article
# 1    b64e2464140cba265a4242ff3f39f786   1.073443  dataset
# 2    16a6f3a0aca07cdb01f995ff888abde2   1.073497  dataset
# 3                        NART98585046   1.253776  article
# 4    22a8ba2b86a9dd291f48148552bbd942   1.259563  dataset
# ..                                ...        ...      ...
# 160  06de034416353eceb124aaee9b78efd1   1.659591  dataset
# 161                      NART70983995   1.665227  article
# 162  eda8eb47c92f99bc97c1ad14fa1c4887   1.683394  dataset
# 163                      NART80860267   1.705854  article
# 164                      NART78101752   1.719341  article
#
#                                                  title  \
# 0                   Large screens as creative clusters
# 1    Data underlying the PhD thesis: Improving Resi...
# 2    Data underlying the PhD thesis: Improving Resi...
# 3    A guide to architecture for the public health ...
# 4    Data underlying the publication: The role of u...
# ..                                                 ...
# 160  Stadtplanungsplan Sant Pau de Segúries - März ...
# 161  COMT genotype affects brain white matter pathw...
# 162  Origin of minicircular mitochondrial genomes i...
# 163  Reduced orbitofrontal cortical thickness in ma...
# 164  Vitamin D Status and Bone Mineral Density in C...
#
#                                            description
# 0    This paper begins by situating the large scree...
# 1    <p>The dataset comprises questionnaire data, a...
# 2    <p>The dataset comprises questionnaire data, a...
# 3    <P><B>Abstract</B></P>  <P><B>Background</B></...
# 4    <p>This dataset contains the results of a pape...
# ..                                                 ...
# 160  Le Plan d’urbanisme municipal (POUM) de Sant P...
# 161  <P><B>Abstract</B></P><P>Increased dopamine av...
# 162  Sample preparation Culture strains of Tsunamia...
# 163  <P><B>Background</B></P><P>The orbitofrontal c...
# 164  <P>Low vitamin D has been implicated in reduce...
#
# [165 rows x 5 columns]

# %%
# 1. 세 개의 데이터프레임 한 번에 병합
merged_df = relevance_df_title.merge(
    relevance_df_description[["ID", "relevance"]], 
    on="ID",
    suffixes=("_title", "_desc")
).merge(
    relevance_df_keyword[["ID", "relevance"]].rename(columns={"relevance": "relevance_key"}), 
    on="ID",
)

# 2. 가중치 합산
a, b, c = 10, 3, 1
merged_df["relevance_raw"] = (
    merged_df["relevance_title"] * a + 
    merged_df["relevance_desc"] * b + 
    merged_df["relevance_key"] * c
) / (a + b + c)

merged_df["relevance_score"] = 100 * (1 - merged_df["relevance_raw"] / 2)

# 3. 필요한 열만 선택 및 정렬
result_df = (merged_df[["ID", "relevance_score", "category", "title", "description"]]
             .rename(columns={"relevance_score": "relevance"})
             .sort_values("relevance", ascending=False)
             .reset_index(drop=True))


display(result_df)
# Out:
#                                    ID  relevance category  \
# 0    b37f0c9413eeb7c45f6fe31cbe3a41ef  93.680328  dataset
# 1    a83eb22a4a62949d83c70662acdf439a  61.288715  dataset
# 2                        NART90662159  52.417946  article
# 3                       NART130570112  51.114548  article
# 4    175af073d420cd3aa8b18fc8f7360e4e  50.354046  dataset
# ..                                ...        ...      ...
# 160  0d0b434d5bc6537b3d40f690a425179a  11.634874  dataset
# 161  5d24ce68a454432a4d8934cd99f506a1  11.631500  dataset
# 162  4af1b0a382e6e6eb8d45722bc496798b  11.513578  dataset
# 163  b33846af9bccac4abbce4af23a43aa0a   9.950542  dataset
# 164                      NART78101752   8.325428  article
#
#                                                  title  \
# 0    Architectural Urbanism: Melbourne/Seoul - KTA ...
# 1    Urban Architectures (Court House, George+Murph...
# 2     Urban Sustainability through Public Architecture
# 3    Sustainable Urbanism and Architectural Design:...
# 4    Master plan for Dandenong Civic Centre - Rush\...
# ..                                                 ...
# 160  Additional file 25 of Implicating genes, pleio...
# 161  Additional file 8 of Implicating genes, pleiot...
# 162  Additional file 27 of Implicating genes, pleio...
# 163                                    He must not cry
# 164  Vitamin D Status and Bone Mineral Density in C...
#
#                                            description
# 0    BACKGROUND: 'Architectural Urbanism: Melbourne...
# 1    RESEARCH BACKGROUND: Court House, George+Murph...
# 2    <P>As the sustainability of contemporary citie...
# 3    <P>This academic article delves into the inter...
# 4    RESEARCH BACKGROUND: Paul Carter's Material Th...
# ..                                                 ...
# 160  <b>External Organisations</b><br/>Queen Mary U...
# 161  <b>External Organisations</b><br/>Queen Mary U...
# 162  <b>External Organisations</b><br/>Queen Mary U...
# 163  An inaugural partnership between ACMI and Asia...
# 164  <P>Low vitamin D has been implicated in reduce...
#
# [165 rows x 5 columns]

# %%
# 로컬 모델 사용
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
from langchain.schema import Document
import pandas as pd

# 검색할 주제와 설명
subject = '기후 데이터 기반의 도시 열섬 현상 분석'
description = '위성 원격탐사 데이터와 국내 기상 관측소 데이터를 결합하여 도시 열섬 현상의 시공간적 패턴을 분석하고, 인공지능 기반 예측 모델을 통해 기후 변화 대응 전략을 모색하는 연구'

# 데이터 로드
processed_df = pd.read_csv('./generated_input_data.csv', encoding='UTF-8', low_memory=False)
vector_df = processed_df[['ID', '제목', '설명', '키워드']]

# 텍스트 결합
texts = (vector_df['제목'] + " " + vector_df['설명'] + " " + vector_df['키워드']).tolist()

# 임베딩 객체 생성
embeddings = HuggingFaceEmbeddings(
    model_name="../model/all-mpnet-base-v2",
    model_kwargs={"device": "cpu"}
)

# Document 객체 생성
docs = [Document(page_content=text, metadata={"id": row.ID}) 
        for text, row in zip(texts, vector_df.itertuples())]

# Chroma 벡터스토어 생성
vectorstore = Chroma.from_documents(
    documents=docs,
    embedding=embeddings,
    # persist_directory="./chroma_db"
)

# 쿼리 생성
query = subject + " " + description

# 유사 문서 20개 검색
k = 20
similar_docs = vectorstore.similarity_search(query, k=k)

# 결과 DataFrame 생성
df_results = pd.DataFrame([
    {
        "ID": doc.metadata.get("id"),
        "제목": vector_df.loc[vector_df['ID'] == doc.metadata.get("id"), "제목"].values[0],
        "설명": vector_df.loc[vector_df['ID'] == doc.metadata.get("id"), "설명"].values[0]
    }
    for doc in similar_docs
])

display(df_results)
